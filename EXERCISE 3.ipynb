# %%
dict_of_lists = {
    "name":["Ginger", "Scout", "Barney", "Buddy"],
    "breed":["Dachshund","Dalmatian","French Bulldog","Maltese"],
    "height":[22,59,30,19],
    "weight":[10,25,24,8],
    "date_of_birth":["2019-03-14", "2008-03-23", "2010-04-10", "2016-04-21"]
}
print (dict_of_lists)
# Out:
# {'name': ['Ginger', 'Scout', 'Barney', 'Buddy'], 'breed': ['Dachshund', 'Dalmatian', 'French Bulldog', 'Maltese'], 'height': [22, 59, 30, 19], 'weight': [10, 25, 24, 8], 'date_of_birth': ['2019-03-14', '2008-03-23', '2010-04-10', '2016-04-21']}

# %%
list_of_dicts = [
    {"name":"Ginger", "breed":"Dachshund", "height":22, "weight": 10, "date_of_birth":"2019-03-14"},
    {"name":"Barney", "breed":"French Bulldog", "height":30, "weight": 24, "date_of_birth":"2010-04-10"},
    {"name":"Butch", "breed":"French Bulldog", "height":28, "weight": 22, "date_of_birth":"2014-08-07"},
    {"name":"Buddy", "breed":"Maltese", "height":19, "weight": 8, "date_of_birth":"2016-04-21"},
]
print(list_of_dicts)
# Out:
# [{'name': 'Ginger', 'breed': 'Dachshund', 'height': 22, 'weight': 10, 'date_of_birth': '2019-03-14'}, {'name': 'Barney', 'breed': 'French Bulldog', 'height': 30, 'weight': 24, 'date_of_birth': '2010-04-10'}, {'name': 'Butch', 'breed': 'French Bulldog', 'height': 28, 'weight': 22, 'date_of_birth': '2014-08-07'}, {'name': 'Buddy', 'breed': 'Maltese', 'height': 19, 'weight': 8, 'date_of_birth': '2016-04-21'}]

# %%
import pandas as pd

# %%
df_dict_columns = pd.DataFrame.from_dict(dict_of_lists)
print(df_dict_columns)
# Out:
#      name           breed  height  weight date_of_birth
# 0  Ginger       Dachshund      22      10    2019-03-14
# 1   Scout       Dalmatian      59      25    2008-03-23
# 2  Barney  French Bulldog      30      24    2010-04-10
# 3   Buddy         Maltese      19       8    2016-04-21

# %%
df_dict_columns = pd.DataFrame(dict_of_lists)
print(df_dict_columns)
# Out:
#      name           breed  height  weight date_of_birth
# 0  Ginger       Dachshund      22      10    2019-03-14
# 1   Scout       Dalmatian      59      25    2008-03-23
# 2  Barney  French Bulldog      30      24    2010-04-10
# 3   Buddy         Maltese      19       8    2016-04-21

# %%
df_dict_index = pd.DataFrame.from_dict(dict_of_lists, orient="index")
print(df_dict_index)
# Out:
#                         0           1               2           3
# name               Ginger       Scout          Barney       Buddy
# breed           Dachshund   Dalmatian  French Bulldog     Maltese
# height                 22          59              30          19
# weight                 10          25              24           8
# date_of_birth  2019-03-14  2008-03-23      2010-04-10  2016-04-21

# %%
file = '04.05_05.06.csv'
df = pd.read_csv(file)

print(df.head())
# Out:
#   Distance from Kottas Unnamed: 1 Unnamed: 2 Unnamed: 3          Unnamed: 4  \
# 0                 (km)  DiffSnow1  DiffSnow2  DiffSnow3  DiffSnowMean_95-97
# 1                    0        NaN         61         41                  51
# 2                  0.5        NaN        NaN        NaN             #DIV/0!
# 3                    1         26        NaN        NaN                  26
# 4                  1.5         36         37        NaN                36.5
#
#   Cluster +150/-20 Cluster +150/-10 Cluster +200/0  Unnamed: 8  AccumulationI  \
# 0              NaN              NaN            NaN         NaN            NaN
# 1               51               51             51         NaN     202.575000
# 2          #DIV/0!          #DIV/0!        #DIV/0!         NaN            NaN
# 3               26               26             26         NaN     103.273529
# 4             36.5             36.5           36.5         NaN     144.980147
#
# ...

# %%
file = '04.05_05.06.csv'

# Define what missing values are
missing_values = ["(km)", "DiffSnow1", "DiffSnow2", "DiffSnow3", "DiffSnowMean_95-97", "#DIV/0!", "Time/a"]

#Read the file into a DataFrame(df2), skip first row, search for missing values and rename the columns
df2 = pd.read_csv(file, skiprows = 1, na_values = missing_values, names = ['Distance_km', 'HeightChange1','HeightChange2', 'HeightChange3','HeightChange4', 'Filter1', 'Filter2','Filter3', 'unknown_1', 'Accumulation_1','Accumulation_2', 'Accumulation_3','Accumulation_4', 'Snow_Density', 'Time_a','mean_without', 'mean_Filter1', 'mean_Filter2', 'mean_Filter3', 'unknown_2'])

# View the head of the DataFrame
print(df2.head())
# Out:
#    Distance_km  HeightChange1  HeightChange2  HeightChange3  HeightChange4  \
# 0          NaN            NaN            NaN            NaN            NaN
# 1          0.0            NaN           61.0           41.0           51.0
# 2          0.5            NaN            NaN            NaN            NaN
# 3          1.0           26.0            NaN            NaN           26.0
# 4          1.5           36.0           37.0            NaN           36.5
#
#    Filter1  Filter2  Filter3  unknown_1  Accumulation_1  Accumulation_2  \
# 0      NaN      NaN      NaN        NaN             NaN             NaN
# 1     51.0     51.0     51.0        NaN      202.575000      202.575000
# 2      NaN      NaN      NaN        NaN             NaN             NaN
# 3     26.0     26.0     26.0        NaN      103.273529      103.273529
# 4     36.5     36.5     36.5        NaN      144.980147      144.980147
#
#    Accumulation_3  Accumulation_4  Snow_Density    Time_a  mean_without  \
# ...

# %%
sort_df2 = df2.sort_values("Distance_km")
print(sort_df2.head())
# Out:
#    Distance_km  HeightChange1  HeightChange2  HeightChange3  HeightChange4  \
# 1          0.0            NaN           61.0           41.0           51.0
# 2          0.5            NaN            NaN            NaN            NaN
# 3          1.0           26.0            NaN            NaN           26.0
# 4          1.5           36.0           37.0            NaN           36.5
# 5          2.0           75.0           68.0            NaN           71.5
#
#    Filter1  Filter2  Filter3  unknown_1  Accumulation_1  Accumulation_2  \
# 1     51.0     51.0     51.0        NaN      202.575000      202.575000
# 2      NaN      NaN      NaN        NaN             NaN             NaN
# 3     26.0     26.0     26.0        NaN      103.273529      103.273529
# 4     36.5     36.5     36.5        NaN      144.980147      144.980147
# 5     71.5     71.5     71.5        NaN      284.002206      284.002206
#
#    Accumulation_3  Accumulation_4  Snow_Density    Time_a  mean_without  \
# ...

# %%
file = 'DAuV.xlsx'
data = pd.ExcelFile(file)
df1 = data.parse("1994") 
df1 = data.parse(0, skiprows=[0], names=['Area', 'Height','Standart_Deviation', 'Median','Period_S', 'Period_E', 'Duration','Density', 'Accumulation'])

#Adding new rows from other sources, check for the new rows in the output
df2["Area"] = df1["Area"]
df2["Area1"] = df1["Area"]
df2["New_row"] = 2*df1["Standart_Deviation"]
df2
# Out:
#      Distance_km  HeightChange1  HeightChange2  HeightChange3  HeightChange4  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            0.0            NaN           61.0           41.0           51.0
# 2            0.5            NaN            NaN            NaN            NaN
# 3            1.0           26.0            NaN            NaN           26.0
# 4            1.5           36.0           37.0            NaN           36.5
# 5            2.0           75.0           68.0            NaN           71.5
# 6            2.5           71.0           77.0            NaN           74.0
# 7            3.0           60.0            NaN            NaN           60.0
# 8            3.5           50.0            NaN            NaN           50.0
# 9            4.0            NaN            NaN            NaN            NaN
# 10           4.5           71.0            NaN            NaN           71.0
# ...

# %%
# Delete a single column
df3 = df2.drop("Area1", axis = 1) #When deleting columns, the index = 1, when deleting rows it must be set index=0
df3
# Out:
#      Distance_km  HeightChange1  HeightChange2  HeightChange3  HeightChange4  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            0.0            NaN           61.0           41.0           51.0
# 2            0.5            NaN            NaN            NaN            NaN
# 3            1.0           26.0            NaN            NaN           26.0
# 4            1.5           36.0           37.0            NaN           36.5
# 5            2.0           75.0           68.0            NaN           71.5
# 6            2.5           71.0           77.0            NaN           74.0
# 7            3.0           60.0            NaN            NaN           60.0
# 8            3.5           50.0            NaN            NaN           50.0
# 9            4.0            NaN            NaN            NaN            NaN
# 10           4.5           71.0            NaN            NaN           71.0
# ...

# %%
# Delete multiple columns
df4 = df3.drop(["unknown_1", "unknown_2"], axis=1)
df4
# Out:
#      Distance_km  HeightChange1  HeightChange2  HeightChange3  HeightChange4  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            0.0            NaN           61.0           41.0           51.0
# 2            0.5            NaN            NaN            NaN            NaN
# 3            1.0           26.0            NaN            NaN           26.0
# 4            1.5           36.0           37.0            NaN           36.5
# 5            2.0           75.0           68.0            NaN           71.5
# 6            2.5           71.0           77.0            NaN           74.0
# 7            3.0           60.0            NaN            NaN           60.0
# 8            3.5           50.0            NaN            NaN           50.0
# 9            4.0            NaN            NaN            NaN            NaN
# 10           4.5           71.0            NaN            NaN           71.0
# ...

# %%
#Delete a row
df5=df4.drop(0, axis = 0)
df5
# Out:
#      Distance_km  HeightChange1  HeightChange2  HeightChange3  HeightChange4  \
# 1            0.0            NaN           61.0           41.0           51.0
# 2            0.5            NaN            NaN            NaN            NaN
# 3            1.0           26.0            NaN            NaN           26.0
# 4            1.5           36.0           37.0            NaN           36.5
# 5            2.0           75.0           68.0            NaN           71.5
# 6            2.5           71.0           77.0            NaN           74.0
# 7            3.0           60.0            NaN            NaN           60.0
# 8            3.5           50.0            NaN            NaN           50.0
# 9            4.0            NaN            NaN            NaN            NaN
# 10           4.5           71.0            NaN            NaN           71.0
# 11           5.0            3.0          -40.0            NaN          -18.5
# ...

# %%
# Dropping duplicates
test = df4.drop_duplicates(subset = ["Snow_Density"])
test
# Out:
#      Distance_km  HeightChange1  HeightChange2  HeightChange3  HeightChange4  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            0.0            NaN           61.0           41.0           51.0
# 50          24.5           64.0          -11.0            NaN           26.5
# 73          36.0            NaN            NaN            NaN            NaN
# 261        130.0           40.0           34.0            NaN           37.0
# 352        175.5           11.0            NaN            NaN           11.0
# 462        230.5           17.0           78.0            NaN           47.5
# 552        275.5           68.0            NaN            NaN           68.0
# 642        320.5           -4.0          -17.0            NaN          -10.5
#
#      Filter1  Filter2  Filter3  Accumulation_1  Accumulation_2  \
# 0        NaN      NaN      NaN             NaN             NaN
# 1       51.0     51.0     51.0      202.575000      202.575000
# ...

# %%
# Setting a column as the indexes
index_test = test.set_index ("Snow_Density")
index_test
# Out:
#               Distance_km  HeightChange1  HeightChange2  HeightChange3  \
# Snow_Density
# NaN                   NaN            NaN            NaN            NaN
# 370.0                 0.0            NaN           61.0           41.0
# 385.0                24.5           64.0          -11.0            NaN
# 365.0                36.0            NaN            NaN            NaN
# 420.0               130.0           40.0           34.0            NaN
# 480.0               175.5           11.0            NaN            NaN
# 425.0               230.5           17.0           78.0            NaN
# 455.0               275.5           68.0            NaN            NaN
# 440.0               320.5           -4.0          -17.0            NaN
#
#               HeightChange4  Filter1  Filter2  Filter3  Accumulation_1  \
# Snow_Density
# NaN                     NaN      NaN      NaN      NaN             NaN
# 370.0                  51.0     51.0     51.0     51.0      202.575000
# ...

# %%
index_test.reset_index()
# Out:
#    Snow_Density  Distance_km  HeightChange1  HeightChange2  HeightChange3  \
# 0           NaN          NaN            NaN            NaN            NaN
# 1         370.0          0.0            NaN           61.0           41.0
# 2         385.0         24.5           64.0          -11.0            NaN
# 3         365.0         36.0            NaN            NaN            NaN
# 4         420.0        130.0           40.0           34.0            NaN
# 5         480.0        175.5           11.0            NaN            NaN
# 6         425.0        230.5           17.0           78.0            NaN
# 7         455.0        275.5           68.0            NaN            NaN
# 8         440.0        320.5           -4.0          -17.0            NaN
#
#    HeightChange4  Filter1  Filter2  Filter3  Accumulation_1  Accumulation_2  \
# 0            NaN      NaN      NaN      NaN             NaN             NaN
# ...

# %%
# Drop an index
index_test2 = test
index_test2
# Out:
#      Distance_km  HeightChange1  HeightChange2  HeightChange3  HeightChange4  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            0.0            NaN           61.0           41.0           51.0
# 50          24.5           64.0          -11.0            NaN           26.5
# 73          36.0            NaN            NaN            NaN            NaN
# 261        130.0           40.0           34.0            NaN           37.0
# 352        175.5           11.0            NaN            NaN           11.0
# 462        230.5           17.0           78.0            NaN           47.5
# 552        275.5           68.0            NaN            NaN           68.0
# 642        320.5           -4.0          -17.0            NaN          -10.5
#
#      Filter1  Filter2  Filter3  Accumulation_1  Accumulation_2  \
# 0        NaN      NaN      NaN             NaN             NaN
# 1       51.0     51.0     51.0      202.575000      202.575000
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\TUT\\Data VIs and Analysis'

# %%
#In this case we have to set the index = False, to get the output correctly
df5.to_csv(r'C:\\Users\\user\\Desktop\\TUT\\Data VIs and Analysis\test1.csv', index = False)

# %%
print(df_dict_index)
# Out:
#                         0           1               2           3
# name               Ginger       Scout          Barney       Buddy
# breed           Dachshund   Dalmatian  French Bulldog     Maltese
# height                 22          59              30          19
# weight                 10          25              24           8
# date_of_birth  2019-03-14  2008-03-23      2010-04-10  2016-04-21

# %%
print(df_dict_index.loc["name"])
# Out:
# 0    Ginger
# 1     Scout
# 2    Barney
# 3     Buddy
# Name: name, dtype: object

# %%
#Check the indexes. What indexes would you need to enter, to get the breed of "Ginger" and "Scout"?
print(df_dict_index.iloc[1:2, 0:2])
# Out:
#                0          1
# breed  Dachshund  Dalmatian

# %%
df_dict_columns[df_dict_columns["name"].isin(["Ginger", "Barney"])]
# Out:
#      name           breed  height  weight date_of_birth
# 0  Ginger       Dachshund      22      10    2019-03-14
# 2  Barney  French Bulldog      30      24    2010-04-10

# %%
df2["Accumulation_1"]>100
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9      False
# 10      True
# 11     False
# 12      True
# 13     False
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# 892    False
# 893    False
# 894    False
# 895    False
# 896    False
# 897    False
# 898    False
# 899    False
# 900    False
# 901    False
# 902    False
# Name: Accumulation_1, Length: 903, dtype: bool

# %%
df2[df2["Accumulation_1"]>400]
# Out:
#      Distance_km  HeightChange1  HeightChange2  HeightChange3  HeightChange4  \
# 56          27.5            NaN          155.0           64.0          109.5
# 60          29.5            NaN          127.0            NaN          127.0
# 68          33.5          112.0            NaN            NaN          112.0
# 91          45.0          134.0            NaN            NaN          134.0
# 536        267.5          103.0          101.0            NaN          102.0
# 537        268.0          101.0          105.0            NaN          103.0
# 578        288.5          118.0            NaN            NaN          118.0
# 592        295.5           93.0            NaN            NaN           93.0
# 609        304.0           75.0          117.0            NaN           96.0
# 625        312.0           86.0           91.0            NaN           88.5
# 705        352.0           92.0            NaN            NaN           92.0
# ...

# %%
#Display only single columns (subsetting):
df2["Snow_Density"]
# Out:
# 0        NaN
# 1      370.0
# 2      370.0
# 3      370.0
# 4      370.0
# 5      370.0
# 6      370.0
# 7      370.0
# 8      370.0
# 9      370.0
# 10     370.0
# 11     370.0
# 12     370.0
# 13     370.0
# 14     370.0
# 15     370.0
# 16     370.0
# 17     370.0
# 18     370.0
# 19     370.0
# 20     370.0
# 21     370.0
# 22     370.0
# 23     370.0
# 24     370.0
# 25     370.0
# 26     370.0
# 27     370.0
# 28     370.0
# 29     370.0
#        ...
# 873      NaN
# 874      NaN
# 875      NaN
# 876      NaN
# 877      NaN
# 878      NaN
# 879      NaN
# 880      NaN
# 881      NaN
# 882      NaN
# 883      NaN
# 884      NaN
# 885      NaN
# 886      NaN
# 887      NaN
# 888      NaN
# 889      NaN
# 890      NaN
# 891      NaN
# 892      NaN
# 893      NaN
# 894      NaN
# 895      NaN
# 896      NaN
# 897      NaN
# 898      NaN
# 899      NaN
# 900      NaN
# 901      NaN
# 902      NaN
# Name: Snow_Density, Length: 903, dtype: float64

# %%
#OR multiple columns (multiple subsetting):
df2[["Snow_Density", "Distance_km"]]
# Out:
#      Snow_Density  Distance_km
# 0             NaN          NaN
# 1           370.0          0.0
# 2           370.0          0.5
# 3           370.0          1.0
# 4           370.0          1.5
# 5           370.0          2.0
# 6           370.0          2.5
# 7           370.0          3.0
# 8           370.0          3.5
# 9           370.0          4.0
# 10          370.0          4.5
# 11          370.0          5.0
# 12          370.0          5.5
# 13          370.0          6.0
# 14          370.0          6.5
# 15          370.0          7.0
# 16          370.0          7.5
# 17          370.0          8.0
# 18          370.0          8.5
# 19          370.0          9.0
# 20          370.0          9.5
# 21          370.0         10.0
# 22          370.0         10.5
# 23          370.0         11.0
# 24          370.0         11.5
# 25          370.0         12.0
# 26          370.0         12.5
# 27          370.0         13.0
# 28          370.0         13.5
# ...
